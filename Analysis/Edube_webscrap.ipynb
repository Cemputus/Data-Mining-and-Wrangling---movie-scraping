# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("letterboxd_movies2.csv")
df
# Out:
#                                           Movie Title  \
# 0                                              Barbie
# 1                                            Parasite
# 2                                        Interstellar
# 3                                          Fight Club
# 4                                          La La Land
# ..                                                ...
# 67                        Scott Pilgrim vs. the World
# 68                                        Taxi Driver
# 69                                         Inside Out
# 70  The Lord of the Rings: The Fellowship of the Ring
# 71                           The Shawshank Redemption
#
#                         Genre(s)  Year of Release  Letterboxd Rating  \
# 0     Adventure, Comedy, Fantasy             2023                3.8
# 1                Drama, Thriller             2019                4.5
# 2       Adventure, Drama, Sci-Fi             2014                4.4
# 3                          Drama             1999                4.3
# 4           Comedy, Drama, Music             2016                4.1
# ..                           ...              ...                ...
# 67       Action, Comedy, Fantasy             2010                3.9
# 68                  Crime, Drama             1976                4.1
# 69  Animation, Adventure, Comedy             2015                3.8
# 70     Adventure, Drama, Fantasy             2001                4.4
# 71                         Drama             1994                4.6
#
#     IMDb Rating  Runtime (mins)  \
# 0           6.8           114.0
# 1           8.5           133.0
# 2           8.7           169.0
# 3           8.8           139.0
# 4           8.0           129.0
# ..          ...             ...
# 67          7.5           113.0
# 68          8.2           114.0
# 69          8.1            95.0
# 70          8.9           179.0
# 71          9.3           142.0
#
#                                              Synopsis  \
# 0   Barbie and Ken are having the time of their li...
# 1   All unemployed, Ki-taek’s family takes peculia...
# 2   The adventures of a group of explorers who mak...
# 3   A ticking-time-bomb insomniac and a slippery s...
# 4   Mia, an aspiring actress, serves lattes to mov...
# ..                                                ...
# 67  As bass guitarist for a garage-rock band, Scot...
# 68  A mentally unstable Vietnam War veteran works ...
# 69  When 11-year-old Riley moves to a new city, he...
# 70  Young hobbit Frodo Baggins, after inheriting a...
# 71  Imprisoned in the 1940s for the double murder ...
#
#                                          Country  \
# 0                  United States, United Kingdom
# 1                                    South Korea
# 2          United States, United Kingdom, Canada
# 3                         Germany, United States
# 4                       United States, Hong Kong
# ..                                           ...
# 67  United States, United Kingdom, Canada, Japan
# 68                                 United States
# 69                                 United States
# 70    New Zealand, United States, United Kingdom
# 71                                 United States
#
#                Original Language Production Studio        Budget  \
# 0               English, Spanish               NaN  $636,238,421
# 1                Korean, English               NaN   $53,369,749
# 2                        English               NaN  $203,227,580
# 3                        English               NaN   $37,030,102
# 4             English, Cantonese               NaN  $151,101,803
# ..                           ...               ...           ...
# 67                       English               NaN   $33,525,605
# 68              English, Spanish               NaN   $28,262,574
# 69  English, Portuguese, Latvian               NaN  $356,461,711
# 70             English, Sindarin               NaN  $319,372,078
# 71                       English               NaN   $28,767,189
#
#    Box Office Gross                                             Awards
# 0      $636,238,421      Won 1 Oscar. 208 wins & 437 nominations total
# 1       $53,369,749     Won 4 Oscars. 316 wins & 266 nominations total
# 2      $203,227,580       Won 1 Oscar. 44 wins & 148 nominations total
# 3       $37,030,102  Nominated for 1 Oscar. 12 wins & 38 nomination...
# 4      $151,101,803     Won 6 Oscars. 242 wins & 307 nominations total
# ..              ...                                                ...
# 67      $33,525,605                     18 wins & 66 nominations total
# 68      $28,262,574  Nominated for 4 Oscars. 22 wins & 21 nominatio...
# 69     $356,461,711       Won 1 Oscar. 99 wins & 118 nominations total
# 70     $319,372,078     Won 4 Oscars. 125 wins & 126 nominations total
# 71      $28,767,189  Nominated for 7 Oscars. 21 wins & 42 nominatio...
#
# [72 rows x 13 columns]

# %%
df1 = pd.read_json("imdbscrapper/IMDB_250_movies.json")
df1
# Out:
#                            title movie_rank                       genres  \
# 0     [The Shawshank Redemption]        [1]                    [[Drama]]
# 1                [The Godfather]        [2]             [[Crime, Drama]]
# 2              [The Dark Knight]        [3]     [[Action, Crime, Drama]]
# 3        [The Godfather Part II]        [4]             [[Crime, Drama]]
# 4                 [12 Angry Men]        [5]             [[Crime, Drama]]
# ..                           ...        ...                          ...
# 245  [A Silent Voice: The Movie]      [246]         [[Animation, Drama]]
# 246                   [The Help]      [247]                    [[Drama]]
# 247              [Amores Perros]      [248]          [[Drama, Thriller]]
# 248                    [Rebecca]      [249]  [[Drama, Mystery, Romance]]
# 249                   [Drishyam]      [250]    [[Crime, Drama, Mystery]]
#
#     release_day release_month release_year movie_length rating vote_count  \
# 0          [14]          [10]       [1994]      2:22:00  [9.3]  [3020598]
# 1          [24]           [3]       [1972]      2:55:00  [9.2]  [2108019]
# 2          [18]           [7]       [2008]      2:32:00    [9]  [2996913]
# 3          [18]          [12]       [1974]      3:22:00    [9]  [1419714]
# 4          [10]           [4]       [1957]      1:36:00    [9]   [916939]
# ..          ...           ...          ...          ...    ...        ...
# 245        [17]           [9]       [2016]      2:10:00  [8.1]   [116937]
# 246        [10]           [8]       [2011]      2:26:00  [8.1]   [509866]
# 247        [13]           [4]       [2000]      2:34:00    [8]   [261263]
# 248        [12]           [4]       [1940]      2:10:00  [8.1]   [153434]
# 249        [31]           [7]       [2015]      2:43:00  [8.2]   [100198]
#
#                                            description
# 0    A banker convicted of uxoricide forms a friend...
# 1    The aging patriarch of an organized crime dyna...
# 2    When a menace known as the Joker wreaks havoc ...
# 3    The early life and career of Vito Corleone in ...
# 4    The jury in a New York City murder trial is fr...
# ..                                                 ...
# 245  A deaf girl, Shoko, is bullied by the popular ...
# 246  An aspiring author during the civil rights mov...
# 247  An amateur dog fighter, a supermodel, and a de...
# 248  A self-conscious woman juggles adjusting to he...
# 249  Desperate measures are taken by a man who trie...
#
# [250 rows x 10 columns]

# %%
df1.to_csv("IMDB_250_movies.csv")
df1.head(6)
# Out:
#                                              title movie_rank  \
# 0                       [The Shawshank Redemption]        [1]
# 1                                  [The Godfather]        [2]
# 2                                [The Dark Knight]        [3]
# 3                          [The Godfather Part II]        [4]
# 4                                   [12 Angry Men]        [5]
# 5  [The Lord of the Rings: The Return of the King]        [6]
#
#                           genres release_day release_month release_year  \
# 0                      [[Drama]]        [14]          [10]       [1994]
# 1               [[Crime, Drama]]        [24]           [3]       [1972]
# 2       [[Action, Crime, Drama]]        [18]           [7]       [2008]
# 3               [[Crime, Drama]]        [18]          [12]       [1974]
# 4               [[Crime, Drama]]        [10]           [4]       [1957]
# 5  [[Adventure, Drama, Fantasy]]        [17]          [12]       [2003]
#
#   movie_length rating vote_count  \
# 0      2:22:00  [9.3]  [3020598]
# 1      2:55:00  [9.2]  [2108019]
# 2      2:32:00    [9]  [2996913]
# 3      3:22:00    [9]  [1419714]
# 4      1:36:00    [9]   [916939]
# 5      3:21:00    [9]  [2063799]
#
#                                          description
# 0  A banker convicted of uxoricide forms a friend...
# 1  The aging patriarch of an organized crime dyna...
# 2  When a menace known as the Joker wreaks havoc ...
# 3  The early life and career of Vito Corleone in ...
# 4  The jury in a New York City murder trial is fr...
# 5  Gandalf and Aragorn lead the World of Men agai...

# %%
df1.columns
# Out:
# Index(['title', 'movie_rank', 'genres', 'release_day', 'release_month',
#        'release_year', 'movie_length', 'rating', 'vote_count', 'description'],
#       dtype='object')

# %%
## reading the csv dataset 
df = pd.read_csv("IMDB_250_movies_cleaned.csv")
df.head(6)
# Out:
#                                            title  movie_rank  \
# 0                       The Shawshank Redemption           1
# 1                                  The Godfather           2
# 2                                The Dark Knight           3
# 3                          The Godfather Part II           4
# 4                                   12 Angry Men           5
# 5  The Lord of the Rings: The Return of the King           6
#
#                       genres  release_day  release_month  release_year  \
# 0                      Drama           14             10          1994
# 1               Crime, Drama           24              3          1972
# 2       Action, Crime, Drama           18              7          2008
# 3               Crime, Drama           18             12          1974
# 4               Crime, Drama           10              4          1957
# 5  Adventure, Drama, Fantasy           17             12          2003
#
#   movie_length  rating  vote_count  \
# 0      2:22:00     9.3     3020598
# 1      2:55:00     9.2     2108019
# 2      2:32:00     9.0     2996913
# 3      3:22:00     9.0     1419714
# 4      1:36:00     9.0      916939
# 5      3:21:00     9.0     2063799
#
#                                          description
# 0  A banker convicted of uxoricide forms a friend...
# 1  The aging patriarch of an organized crime dyna...
# 2  When a menace known as the Joker wreaks havoc ...
# 3  The early life and career of Vito Corleone in ...
# 4  The jury in a New York City murder trial is fr...
# 5  Gandalf and Aragorn lead the World of Men agai...

# %%
df.columns
# Out:
# Index(['title', 'movie_rank', 'genres', 'release_day', 'release_month',
#        'release_year', 'movie_length', 'rating', 'vote_count', 'description'],
#       dtype='object')

# %%
from datetime import date

# %%
df[['release_day','release_month','release_year']] = df[['release_day','release_month','release_year']].astype('str')

# %%
df['date'] = pd.to_datetime(df['release_year'] + '-' +  df['release_month'] + '-'+ df['release_day'])
df['date']
# Out:
# 0     1994-10-14
# 1     1972-03-24
# 2     2008-07-18
# 3     1974-12-18
# 4     1957-04-10
#          ...
# 245   2016-09-17
# 246   2011-08-10
# 247   2000-04-13
# 248   1940-04-12
# 249   2015-07-31
# Name: date, Length: 250, dtype: datetime64[ns]

# %%
df
# Out:
#                          title  movie_rank                   genres  \
# 0     The Shawshank Redemption           1                    Drama
# 1                The Godfather           2             Crime, Drama
# 2              The Dark Knight           3     Action, Crime, Drama
# 3        The Godfather Part II           4             Crime, Drama
# 4                 12 Angry Men           5             Crime, Drama
# ..                         ...         ...                      ...
# 245  A Silent Voice: The Movie         246         Animation, Drama
# 246                   The Help         247                    Drama
# 247              Amores Perros         248          Drama, Thriller
# 248                    Rebecca         249  Drama, Mystery, Romance
# 249                   Drishyam         250    Crime, Drama, Mystery
#
#     release_day release_month release_year movie_length  rating  vote_count  \
# 0            14            10         1994      2:22:00     9.3     3020598
# 1            24             3         1972      2:55:00     9.2     2108019
# 2            18             7         2008      2:32:00     9.0     2996913
# 3            18            12         1974      3:22:00     9.0     1419714
# 4            10             4         1957      1:36:00     9.0      916939
# ..          ...           ...          ...          ...     ...         ...
# 245          17             9         2016      2:10:00     8.1      116937
# 246          10             8         2011      2:26:00     8.1      509866
# 247          13             4         2000      2:34:00     8.0      261263
# 248          12             4         1940      2:10:00     8.1      153434
# 249          31             7         2015      2:43:00     8.2      100198
#
#                                            description       date
# 0    A banker convicted of uxoricide forms a friend... 1994-10-14
# 1    The aging patriarch of an organized crime dyna... 1972-03-24
# 2    When a menace known as the Joker wreaks havoc ... 2008-07-18
# 3    The early life and career of Vito Corleone in ... 1974-12-18
# 4    The jury in a New York City murder trial is fr... 1957-04-10
# ..                                                 ...        ...
# 245  A deaf girl, Shoko, is bullied by the popular ... 2016-09-17
# 246  An aspiring author during the civil rights mov... 2011-08-10
# 247  An amateur dog fighter, a supermodel, and a de... 2000-04-13
# 248  A self-conscious woman juggles adjusting to he... 1940-04-12
# 249  Desperate measures are taken by a man who trie... 2015-07-31
#
# [250 rows x 11 columns]

# %%
df.head(4)
# Out:
#                       title  movie_rank                genres release_day  \
# 0  The Shawshank Redemption           1                 Drama          14
# 1             The Godfather           2          Crime, Drama          24
# 2           The Dark Knight           3  Action, Crime, Drama          18
# 3     The Godfather Part II           4          Crime, Drama          18
#
#   release_month release_year movie_length  rating  vote_count  \
# 0            10         1994      2:22:00     9.3     3020598
# 1             3         1972      2:55:00     9.2     2108019
# 2             7         2008      2:32:00     9.0     2996913
# 3            12         1974      3:22:00     9.0     1419714
#
#                                          description       date
# 0  A banker convicted of uxoricide forms a friend... 1994-10-14
# 1  The aging patriarch of an organized crime dyna... 1972-03-24
# 2  When a menace known as the Joker wreaks havoc ... 2008-07-18
# 3  The early life and career of Vito Corleone in ... 1974-12-18

# %%
df['Release_Month_name'] = df.date.dt.month_name()
df.head(4)
# Out:
#                       title  movie_rank                genres release_day  \
# 0  The Shawshank Redemption           1                 Drama          14
# 1             The Godfather           2          Crime, Drama          24
# 2           The Dark Knight           3  Action, Crime, Drama          18
# 3     The Godfather Part II           4          Crime, Drama          18
#
#   release_month release_year movie_length  rating  vote_count  \
# 0            10         1994      2:22:00     9.3     3020598
# 1             3         1972      2:55:00     9.2     2108019
# 2             7         2008      2:32:00     9.0     2996913
# 3            12         1974      3:22:00     9.0     1419714
#
#                                          description       date  \
# 0  A banker convicted of uxoricide forms a friend... 1994-10-14
# 1  The aging patriarch of an organized crime dyna... 1972-03-24
# 2  When a menace known as the Joker wreaks havoc ... 2008-07-18
# 3  The early life and career of Vito Corleone in ... 1974-12-18
#
#   Release_Month_name
# 0            October
# 1              March
# 2               July
# 3           December

# %%
df['Release_week_day'] = df.date.dt.day_name()

# %%
df.head(4)
# Out:
#                       title  movie_rank                genres release_day  \
# 0  The Shawshank Redemption           1                 Drama          14
# 1             The Godfather           2          Crime, Drama          24
# 2           The Dark Knight           3  Action, Crime, Drama          18
# 3     The Godfather Part II           4          Crime, Drama          18
#
#   release_month release_year movie_length  rating  vote_count  \
# 0            10         1994      2:22:00     9.3     3020598
# 1             3         1972      2:55:00     9.2     2108019
# 2             7         2008      2:32:00     9.0     2996913
# 3            12         1974      3:22:00     9.0     1419714
#
#                                          description       date  \
# 0  A banker convicted of uxoricide forms a friend... 1994-10-14
# 1  The aging patriarch of an organized crime dyna... 1972-03-24
# 2  When a menace known as the Joker wreaks havoc ... 2008-07-18
# 3  The early life and career of Vito Corleone in ... 1974-12-18
#
#   Release_Month_name Release_week_day
# 0            October           Friday
# 1              March           Friday
# 2               July           Friday
# 3           December        Wednesday

# %%
df.columns
# Out:
# Index(['title', 'movie_rank', 'genres', 'release_day', 'release_month',
#        'release_year', 'movie_length', 'rating', 'vote_count', 'description',
#        'date', 'Release_Month_name', 'Release_week_day'],
#       dtype='object')

# %%
cleaned_data = pd.read_csv('IMDB_250_movies_cleaned2.csv')
cleaned_data.head(4)
# Out:
#                       title  movie_rank                genres  release_day  \
# 0  The Shawshank Redemption           1                 Drama           14
# 1             The Godfather           2          Crime, Drama           24
# 2           The Dark Knight           3  Action, Crime, Drama           18
# 3     The Godfather Part II           4          Crime, Drama           18
#
#    release_month  release_year movie_length  rating  vote_count  \
# 0             10          1994      2:22:00     9.3     3020598
# 1              3          1972      2:55:00     9.2     2108019
# 2              7          2008      2:32:00     9.0     2996913
# 3             12          1974      3:22:00     9.0     1419714
#
#                                          description  \
# 0  A banker convicted of uxoricide forms a friend...
# 1  The aging patriarch of an organized crime dyna...
# 2  When a menace known as the Joker wreaks havoc ...
# 3  The early life and career of Vito Corleone in ...
#
#                             Cast (Main Actors) Box Office Gross  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton      $28,767,189
# 1         Marlon Brando, Al Pacino, James Caan     $136,381,073
# 2  Christian Bale, Heath Ledger, Aaron Eckhart     $534,987,076
# 3     Al Pacino, Robert De Niro, Robert Duvall      $47,834,595
#
#                                               Awards
# 0  Nominated for 7 Oscars. 21 wins & 42 nominatio...
# 1       Won 3 Oscars. 31 wins & 31 nominations total
# 2     Won 2 Oscars. 164 wins & 165 nominations total
# 3       Won 6 Oscars. 17 wins & 21 nominations total

# %%
cleaned_data.columns
# Out:
# Index(['title', 'movie_rank', 'genres', 'release_day', 'release_month',
#        'release_year', 'movie_length', 'rating', 'vote_count', 'description',
#        'Cast (Main Actors)', 'Box Office Gross', 'Awards'],
#       dtype='object')

# %%
cleaned_data[['release_day','release_month','release_year']] = cleaned_data[['release_day','release_month','release_year']].astype('str')

# %%
cleaned_data.dtypes
# Out:
# title                  object
# movie_rank              int64
# genres                 object
# release_day            object
# release_month          object
# release_year           object
# movie_length           object
# rating                float64
# vote_count              int64
# description            object
# Cast (Main Actors)     object
# Box Office Gross       object
# Awards                 object
# dtype: object

# %%
cleaned_data.columns
# Out:
# Index(['title', 'movie_rank', 'genres', 'release_day', 'release_month',
#        'release_year', 'movie_length', 'rating', 'vote_count', 'description',
#        'Cast (Main Actors)', 'Box Office Gross', 'Awards'],
#       dtype='object')

# %%
from datetime import date
cleaned_data['Date'] = pd.to_datetime(cleaned_data['release_year'] + '-' +  cleaned_data['release_month'] + '-' + cleaned_data['release_day'])
cleaned_data.head(4)
# Out:
#                       title  movie_rank                genres release_day  \
# 0  The Shawshank Redemption           1                 Drama          14
# 1             The Godfather           2          Crime, Drama          24
# 2           The Dark Knight           3  Action, Crime, Drama          18
# 3     The Godfather Part II           4          Crime, Drama          18
#
#   release_month release_year movie_length  rating  vote_count  \
# 0            10         1994      2:22:00     9.3     3020598
# 1             3         1972      2:55:00     9.2     2108019
# 2             7         2008      2:32:00     9.0     2996913
# 3            12         1974      3:22:00     9.0     1419714
#
#                                          description  \
# 0  A banker convicted of uxoricide forms a friend...
# 1  The aging patriarch of an organized crime dyna...
# 2  When a menace known as the Joker wreaks havoc ...
# 3  The early life and career of Vito Corleone in ...
#
#                             Cast (Main Actors) Box Office Gross  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton      $28,767,189
# 1         Marlon Brando, Al Pacino, James Caan     $136,381,073
# 2  Christian Bale, Heath Ledger, Aaron Eckhart     $534,987,076
# 3     Al Pacino, Robert De Niro, Robert Duvall      $47,834,595
#
#                                               Awards       Date
# 0  Nominated for 7 Oscars. 21 wins & 42 nominatio... 1994-10-14
# 1       Won 3 Oscars. 31 wins & 31 nominations total 1972-03-24
# 2     Won 2 Oscars. 164 wins & 165 nominations total 2008-07-18
# 3       Won 6 Oscars. 17 wins & 21 nominations total 1974-12-18

# %%
cleaned_data.columns
# Out:
# Index(['title', 'movie_rank', 'genres', 'release_day', 'release_month',
#        'release_year', 'movie_length', 'rating', 'vote_count', 'description',
#        'Cast (Main Actors)', 'Box Office Gross', 'Awards', 'Date'],
#       dtype='object')

# %%
cleaned_data['Release_Week_day'] = cleaned_data.Date.dt.day_name()
cleaned_data['Release_Month']    = cleaned_data.Date.dt.month_name()
# Out:
#                                              title  movie_rank  \
# 0                         The Shawshank Redemption           1
# 1                                    The Godfather           2
# 2                                  The Dark Knight           3
# 3                            The Godfather Part II           4
# 4    The Lord of the Rings: The Return of the King           6
# ..                                             ...         ...
# 216                                  Into the Wild         243
# 217                                  Groundhog Day         245
# 218                      A Silent Voice: The Movie         246
# 219                                       The Help         247
# 220                                  Amores Perros         248
#
#                           genres release_day release_month release_year  \
# 0                          Drama          14            10         1994
# 1                   Crime, Drama          24             3         1972
# 2           Action, Crime, Drama          18             7         2008
# 3                   Crime, Drama          18            12         1974
# 4      Adventure, Drama, Fantasy          17            12         2003
# ..                           ...         ...           ...          ...
# 216  Adventure, Biography, Drama          19            10         2007
# 217       Comedy, Drama, Fantasy          12             2         1993
# 218             Animation, Drama          17             9         2016
# 219                        Drama          10             8         2011
# 220              Drama, Thriller          13             4         2000
#
#     movie_length  rating  vote_count  \
# 0        2:22:00     9.3     3020598
# 1        2:55:00     9.2     2108019
# 2        2:32:00     9.0     2996913
# 3        3:22:00     9.0     1419714
# 4        3:21:00     9.0     2063799
# ..           ...     ...         ...
# 216      2:28:00     8.1      676109
# 217      1:41:00     8.0      712394
# 218      2:10:00     8.1      116937
# 219      2:26:00     8.1      509866
# 220      2:34:00     8.0      261263
#
#                                            description  \
# 0    A banker convicted of uxoricide forms a friend...
# 1    The aging patriarch of an organized crime dyna...
# 2    When a menace known as the Joker wreaks havoc ...
# 3    The early life and career of Vito Corleone in ...
# 4    Gandalf and Aragorn lead the World of Men agai...
# ..                                                 ...
# 216  After graduating from Emory University, top st...
# 217  A narcissistic, self-centered weatherman finds...
# 218  A deaf girl, Shoko, is bullied by the popular ...
# 219  An aspiring author during the civil rights mov...
# 220  An amateur dog fighter, a supermodel, and a de...
#
#                                     Cast (Main Actors) Box Office Gross  \
# 0              Tim Robbins, Morgan Freeman, Bob Gunton      $28,767,189
# 1                 Marlon Brando, Al Pacino, James Caan     $136,381,073
# 2          Christian Bale, Heath Ledger, Aaron Eckhart     $534,987,076
# 3             Al Pacino, Robert De Niro, Robert Duvall      $47,834,595
# 4           Elijah Wood, Viggo Mortensen, Ian McKellen     $381,878,219
# ..                                                 ...              ...
# 216       Emile Hirsch, Vince Vaughn, Catherine Keener      $18,354,356
# 217        Bill Murray, Andie MacDowell, Chris Elliott      $71,107,962
# 218                 Miyu Irino, Saori Hayami, Aoi Yûki       $1,079,689
# 219           Viola Davis, Emma Stone, Octavia Spencer     $169,708,112
# 220  Emilio Echevarría, Gael García Bernal, Goya To...       $5,408,467
#
#                                                 Awards       Date  \
# 0    Nominated for 7 Oscars. 21 wins & 42 nominatio... 1994-10-14
# 1         Won 3 Oscars. 31 wins & 31 nominations total 1972-03-24
# 2       Won 2 Oscars. 164 wins & 165 nominations total 2008-07-18
# 3         Won 6 Oscars. 17 wins & 21 nominations total 1974-12-18
# 4      Won 11 Oscars. 215 wins & 124 nominations total 2003-12-17
# ..                                                 ...        ...
# 216  Nominated for 2 Oscars. 23 wins & 106 nominati... 2007-10-19
# 217     Won 1 BAFTA Award7 wins & 17 nominations total 1993-02-12
# 218                       6 wins & 9 nominations total 2016-09-17
# 219       Won 1 Oscar. 79 wins & 121 nominations total 2011-08-10
# 220  Nominated for 1 Oscar. 55 wins & 24 nomination... 2000-04-13
#
#     Release_Week_day Release_Month
# 0             Friday       October
# 1             Friday         March
# 2             Friday          July
# 3          Wednesday      December
# 4          Wednesday      December
# ..               ...           ...
# 216           Friday       October
# 217           Friday      February
# 218         Saturday     September
# 219        Wednesday        August
# 220         Thursday         April
#
# [221 rows x 16 columns]

# %%
cleaned_data.head(3)
# Out:
#                       title  movie_rank                genres release_day  \
# 0  The Shawshank Redemption           1                 Drama          14
# 1             The Godfather           2          Crime, Drama          24
# 2           The Dark Knight           3  Action, Crime, Drama          18
#
#   release_month release_year movie_length  rating  vote_count  \
# 0            10         1994      2:22:00     9.3     3020598
# 1             3         1972      2:55:00     9.2     2108019
# 2             7         2008      2:32:00     9.0     2996913
#
#                                          description  \
# 0  A banker convicted of uxoricide forms a friend...
# 1  The aging patriarch of an organized crime dyna...
# 2  When a menace known as the Joker wreaks havoc ...
#
#                             Cast (Main Actors) Box Office Gross  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton      $28,767,189
# 1         Marlon Brando, Al Pacino, James Caan     $136,381,073
# 2  Christian Bale, Heath Ledger, Aaron Eckhart     $534,987,076
#
#                                               Awards       Date  \
# 0  Nominated for 7 Oscars. 21 wins & 42 nominatio... 1994-10-14
# 1       Won 3 Oscars. 31 wins & 31 nominations total 1972-03-24
# 2     Won 2 Oscars. 164 wins & 165 nominations total 2008-07-18
#
#   Release_Week_day Release_Month
# 0           Friday       October
# 1           Friday         March
# 2           Friday          July

# %%
cleaned_data.columns
# Out:
# Index(['title', 'movie_rank', 'genres', 'release_day', 'release_month',
#        'release_year', 'movie_length', 'rating', 'vote_count', 'description',
#        'Cast (Main Actors)', 'Box Office Gross', 'Awards', 'Date',
#        'Release_Week_day', 'Release_Month'],
#       dtype='object')

# %%
cleaned_reformed = cleaned_data.drop(columns = ['release_day'])
cleaned_reformed = cleaned_reformed.drop(columns=['movie_rank'])
cleaned_reformed = cleaned_reformed.drop(columns=['release_month'])
cleaned_reformed

# %%
cleaned_reformed.rename(columns={'description':'Synopsis'},inplace=True)
cleaned_reformed.head(4)
# Out:
#                       title                genres release_year movie_length  \
# 0  The Shawshank Redemption                 Drama         1994      2:22:00
# 1             The Godfather          Crime, Drama         1972      2:55:00
# 2           The Dark Knight  Action, Crime, Drama         2008      2:32:00
# 3     The Godfather Part II          Crime, Drama         1974      3:22:00
#
#    rating  vote_count                                           Synopsis  \
# 0     9.3     3020598  A banker convicted of uxoricide forms a friend...
# 1     9.2     2108019  The aging patriarch of an organized crime dyna...
# 2     9.0     2996913  When a menace known as the Joker wreaks havoc ...
# 3     9.0     1419714  The early life and career of Vito Corleone in ...
#
#                             Cast (Main Actors) Box Office Gross  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton      $28,767,189
# 1         Marlon Brando, Al Pacino, James Caan     $136,381,073
# 2  Christian Bale, Heath Ledger, Aaron Eckhart     $534,987,076
# 3     Al Pacino, Robert De Niro, Robert Duvall      $47,834,595
#
#                                               Awards       Date  \
# 0  Nominated for 7 Oscars. 21 wins & 42 nominatio... 1994-10-14
# 1       Won 3 Oscars. 31 wins & 31 nominations total 1972-03-24
# 2     Won 2 Oscars. 164 wins & 165 nominations total 2008-07-18
# 3       Won 6 Oscars. 17 wins & 21 nominations total 1974-12-18
#
#   Release_Week_day Release_Month
# 0           Friday       October
# 1           Friday         March
# 2           Friday          July
# 3        Wednesday      December

# %% [markdown]
# ## QUESTION ONE

# %%
## Most common genres
genre_data = cleaned_reformed.groupby(['genres'],as_index=None,observed=True)['genres'].agg({'count'})
genre_data
# Out:
#                          genres  count
# 0             Action, Adventure      2
# 1      Action, Adventure, Drama      2
# 2    Action, Adventure, Fantasy      5
# 3     Action, Adventure, Horror      1
# 4     Action, Adventure, Sci-Fi      7
# ..                          ...    ...
# 97    Horror, Mystery, Thriller      1
# 98               Horror, Sci-Fi      1
# 99   Mystery, Romance, Thriller      1
# 100           Mystery, Thriller      1
# 101                     Western      1
#
# [102 rows x 2 columns]

# %%
## Extracting  most released genres
# The most released genres are below
genre_data.loc[genre_data['count'] >= 7][['genres','count']]
# Out:
#                           genres  count
# 4      Action, Adventure, Sci-Fi      7
# 34  Animation, Adventure, Comedy      7
# 48     Biography, Drama, History      8
# 63                  Crime, Drama     11
# 66         Crime, Drama, Mystery      8
# 71                         Drama     16

# %% [markdown]
# Hence the top released genres are `Drama`, `crime,Drama`, `Biography, Drama, History`,`Animation, Adventure, Comedy` and `Action, Adventure, Sci-Fi`

# %%
## A countplot showing the most release'd genres
plt.figure(figsize=(30,10))
sns.countplot(data=cleaned_reformed,x='genres')
plt.xticks(rotation = 90)
plt.title('a countplot showing the most released genres'.title())
# Out:
# Text(0.5, 1.0, 'A Countplot Showing The Most Released Genres')

# %%
from collections import Counter
from wordcloud import WordCloud

# Split and count genre occurrences
all_genres = cleaned_reformed['genres'].dropna().str.split(', ').sum()
genre_counts = Counter(all_genres)

# Identify the most frequent genre
most_frequent_genre = genre_counts.most_common(1)[0]
most_frequent_genre
# Out:
# ('Drama', 159)

# %%
# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis')
wordcloud.generate_from_frequencies(genre_counts)

# Plot word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('IMDb Top Movie Genres')
plt.show()

# %% [markdown]
# ## QUESTION TWO

# %%
cleaned_reformed.columns
# Out:
# Index(['title', 'genres', 'release_year', 'movie_length', 'rating',
#        'vote_count', 'Synopsis', 'Cast (Main Actors)', 'Box Office Gross',
#        'Awards', 'Date', 'Release_Week_day', 'Release_Month'],
#       dtype='object')

# %%
## Average rating of the imdb movies scaped
average_rating = cleaned_reformed.agg({'rating':'mean'})
average_rating
# Out:
# rating    8.31267
# dtype: float64

# %% [markdown]
# ## QUESTION THREE

# %% [markdown]
# #### Drama Dominates the list

# %%
# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='black', colormap='viridis')
wordcloud.generate_from_frequencies(genre_counts)

# Plot word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('IMDb Top Movie Genres')
plt.show()

# %% [markdown]
# #### High IMDB ratings

# %%
average_rating = cleaned_reformed.agg({'rating':'mean'})
average_rating
# Out:
# rating    8.31267
# dtype: float64

# %% [markdown]
# #### Most Popular Movie Decdes

# %%
Rate_sorted_data = cleaned_reformed.sort_values(by='rating',ascending=False)
Rate_sorted_data.head(10)
# Out:
#                                                 title  \
# 0                            The Shawshank Redemption
# 1                                       The Godfather
# 2                                     The Dark Knight
# 3                               The Godfather Part II
# 4       The Lord of the Rings: The Return of the King
# 5                                    Schindler's List
# 6                                        Pulp Fiction
# 7   The Lord of the Rings: The Fellowship of the Ring
# 10              The Lord of the Rings: The Two Towers
# 12                                          Inception
#
#                        genres release_year movie_length  rating  vote_count  \
# 0                       Drama         1994      2:22:00     9.3     3020598
# 1                Crime, Drama         1972      2:55:00     9.2     2108019
# 2        Action, Crime, Drama         2008      2:32:00     9.0     2996913
# 3                Crime, Drama         1974      3:22:00     9.0     1419714
# 4   Adventure, Drama, Fantasy         2003      3:21:00     9.0     2063799
# 5   Biography, Drama, History         1993      3:15:00     9.0     1512153
# 6                Crime, Drama         1994      2:34:00     8.9     2317747
# 7   Adventure, Drama, Fantasy         2001      2:58:00     8.9     2092797
# 10  Adventure, Drama, Fantasy         2002      2:59:00     8.8     1859956
# 12  Action, Adventure, Sci-Fi         2010      2:28:00     8.8     2663522
#
#                                              Synopsis  \
# 0   A banker convicted of uxoricide forms a friend...
# 1   The aging patriarch of an organized crime dyna...
# 2   When a menace known as the Joker wreaks havoc ...
# 3   The early life and career of Vito Corleone in ...
# 4   Gandalf and Aragorn lead the World of Men agai...
# 5   In German-occupied Poland during World War II,...
# 6   The lives of two mob hitmen, a boxer, a gangst...
# 7   A meek Hobbit from the Shire and eight compani...
# 10  While Frodo and Sam edge closer to Mordor with...
# 12  A thief who steals corporate secrets through t...
#
#                                    Cast (Main Actors) Box Office Gross  \
# 0             Tim Robbins, Morgan Freeman, Bob Gunton      $28,767,189
# 1                Marlon Brando, Al Pacino, James Caan     $136,381,073
# 2         Christian Bale, Heath Ledger, Aaron Eckhart     $534,987,076
# 3            Al Pacino, Robert De Niro, Robert Duvall      $47,834,595
# 4          Elijah Wood, Viggo Mortensen, Ian McKellen     $381,878,219
# 5            Liam Neeson, Ralph Fiennes, Ben Kingsley      $96,898,818
# 6       John Travolta, Uma Thurman, Samuel L. Jackson     $107,928,762
# 7            Elijah Wood, Ian McKellen, Orlando Bloom     $319,372,078
# 10         Elijah Wood, Ian McKellen, Viggo Mortensen     $345,518,923
# 12  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...     $292,587,330
#
#                                                Awards       Date  \
# 0   Nominated for 7 Oscars. 21 wins & 42 nominatio... 1994-10-14
# 1        Won 3 Oscars. 31 wins & 31 nominations total 1972-03-24
# 2      Won 2 Oscars. 164 wins & 165 nominations total 2008-07-18
# 3        Won 6 Oscars. 17 wins & 21 nominations total 1974-12-18
# 4     Won 11 Oscars. 215 wins & 124 nominations total 2003-12-17
# 5        Won 7 Oscars. 91 wins & 49 nominations total 1993-02-04
# 6         Won 1 Oscar. 69 wins & 72 nominations total 1994-10-14
# 7      Won 4 Oscars. 125 wins & 126 nominations total 2001-12-19
# 10     Won 2 Oscars. 132 wins & 138 nominations total 2002-12-18
# 12     Won 4 Oscars. 159 wins & 220 nominations total 2010-07-16
#
#    Release_Week_day Release_Month
# 0            Friday       October
# 1            Friday         March
# 2            Friday          July
# 3         Wednesday      December
# 4         Wednesday      December
# 5          Thursday      February
# 6            Friday       October
# 7         Wednesday      December
# 10        Wednesday      December
# 12           Friday          July

# %% [markdown]
# #### WEEK DAYS AND MONTHS IN WHICH MOVIES MOST RELEASED

# %% [markdown]
# - Graphically

# %%
all_week_days = cleaned_reformed['Release_Week_day'].dropna().str.split(', ').sum()
day_counts = Counter(all_week_days)

# Identify the most frequent day_counts
most_all_week_days = day_counts.most_common(1)[0]
day_counts
# Out:
# Counter({'Friday': 102,
#          'Wednesday': 52,
#          'Thursday': 34,
#          'Tuesday': 14,
#          'Saturday': 9,
#          'Monday': 7,
#          'Sunday': 3})

# %%
## Days in which most movies are released
wordcloud = WordCloud(width=800, height=400, background_color='black', colormap='viridis')
wordcloud.generate_from_frequencies(day_counts)

# Plot word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Week Days In Which Movies Are Mostly Released')
plt.show()
# We see that most movies are released on Friday,Wednesday and Thurseday

# %%
cleaned_reformed.columns
# Out:
# Index(['title', 'genres', 'release_year', 'movie_length', 'rating',
#        'vote_count', 'Synopsis', 'Cast (Main Actors)', 'Box Office Gross',
#        'Awards', 'Date', 'Release_Week_day', 'Release_Month'],
#       dtype='object')

# %% [markdown]
# - Statistics

# %%
cleaned_reformed.groupby(['Release_Week_day'],as_index=False)['Release_Week_day'].agg({'count'})
# We see that most movies are released on Friday,Wednesday and Thurseday
# Out:
#   Release_Week_day  count
# 0           Friday    102
# 1           Monday      7
# 2         Saturday      9
# 3           Sunday      3
# 4         Thursday     34
# 5          Tuesday     14
# 6        Wednesday     52

# %% [markdown]
# ## The months

# %%
all_months = cleaned_reformed['Release_Month'].dropna().str.split(', ').sum()
month_counts = Counter(all_months)

# Identify the most frequent day_counts
most_all_months = month_counts.most_common(1)[0]
month_counts
# Out:
# Counter({'December': 27,
#          'November': 23,
#          'June': 22,
#          'July': 20,
#          'February': 20,
#          'March': 18,
#          'September': 18,
#          'May': 17,
#          'October': 16,
#          'January': 16,
#          'August': 14,
#          'April': 10})

# %%
## Months in which movies are mostly released
wordcloud = WordCloud(width=800, height=400, background_color='black', colormap='viridis')
wordcloud.generate_from_frequencies(month_counts)

# Plot word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Months in Which Movies Are Mostly Released')
plt.show()
## Most movies are released in December, November and june

# %%
cleaned_reformed.groupby(['Release_Month'],as_index=False)['Release_Month'].agg({'count'})
## Most movies are released in December, November and june
# Out:
#    Release_Month  count
# 0          April     10
# 1         August     14
# 2       December     27
# 3       February     20
# 4        January     16
# 5           July     20
# 6           June     22
# 7          March     18
# 8            May     17
# 9       November     23
# 10       October     16
# 11     September     18

# %% [markdown]
# #### Many movies with high IMDb ratings correlates win Awards

# %%
genre_data.loc[genre_data['count'] >= 7][['genres','count']]
